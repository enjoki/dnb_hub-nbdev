# %% [markdown]
# ## Fetching Market prices with API

# %% [markdown]
# ## Import libraries

# %%
import pandas as pd
import numpy as np
import plotly
import os
import json
import requests

import plotly.express as px

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %% [markdown]
# ### function to make AI calls

# %%
# function to fetch data
def fetch_data(url):
    response = requests.get(url)

    if response.status_code == 200:
        data = response.json()
        df = pd.DataFrame(data)
        return df
    else:
        print(f"Failed to fetch data: {response.status_code} ")

# %% [markdown]
# ### Fetch data from api endpoint

# %%
url = "https://fdw.fews.net/api/marketprice/"
data = fetch_data(url)

# %%
market_prices = data
market_prices.shape
# Out:
# (1360022, 47)

# %% [markdown]
# ### view the data

# %%
market_prices.head()
# Out:
#   geographic_group fewsnet_region  country country_code market     cpcv2  \
# 0   Western Africa    West Africa  Nigeria           NG    Aba  P21421AA
# 1   Western Africa    West Africa  Nigeria           NG    Aba  P21421AA
# 2   Western Africa    West Africa  Nigeria           NG    Aba  P21421AA
# 3   Western Africa    West Africa  Nigeria           NG    Aba  P21421AA
# 4   Western Africa    West Africa  Nigeria           NG    Aba  P21421AA
#
#      cpcv2_description               product  \
# 0  Groundnuts, shelled  Groundnuts (Shelled)
# 1  Groundnuts, shelled  Groundnuts (Shelled)
# 2  Groundnuts, shelled  Groundnuts (Shelled)
# 3  Groundnuts, shelled  Groundnuts (Shelled)
# 4  Groundnuts, shelled  Groundnuts (Shelled)
#
#                                source_organization  \
# 0  Famine Early Warning Systems Network (FEWS NET)
# 1  Famine Early Warning Systems Network (FEWS NET)
# 2  Famine Early Warning Systems Network (FEWS NET)
# 3  Famine Early Warning Systems Network (FEWS NET)
# 4  Famine Early Warning Systems Network (FEWS NET)
#
#                                      source_document collection_status  \
# 0  Famine Early Warning Systems Network (FEWS NET...         Published
# 1  Famine Early Warning Systems Network (FEWS NET...         Published
# 2  Famine Early Warning Systems Network (FEWS NET...         Published
# 3  Famine Early Warning Systems Network (FEWS NET...         Published
# 4  Famine Early Warning Systems Network (FEWS NET...         Published
#
#   period_date price_type product_source    unit unit_type unit_name currency  \
# 0  2014-07-31     Retail          Local      kg    Weight  Kilogram      NGN
# 1  2014-07-31  Wholesale          Local  100_kg    Weight    100 kg      NGN
# 2  2014-08-31     Retail          Local      kg    Weight  Kilogram      NGN
# 3  2014-08-31  Wholesale          Local  100_kg    Weight    100 kg      NGN
# 4  2014-09-30     Retail          Local      kg    Weight  Kilogram      NGN
#
#        status      value  availability availability_description common_unit  \
# 0  Aggregated    119.050           NaN                     None          kg
# 1  Aggregated  28000.000           NaN                     None          kg
# 2  Aggregated    162.895           NaN                     None          kg
# 3  Aggregated  28000.000           NaN                     None          kg
# 4  Aggregated    206.740           NaN                     None          kg
#
#   common_currency  exchange_rate  common_unit_price  common_currency_price  \
# 0             USD        0.00621            119.050               0.739301
# 1             USD        0.00621            280.000               1.738800
# 2             USD        0.00623            162.895               1.014836
# 3             USD        0.00623            280.000               1.744400
# 4             USD        0.00620            206.740               1.281788
#
#    start_date  id  datacollectionperiod  datacollection  datasourcedocument  \
# 0  2014-07-01 NaN                   NaN             NaN                 282
# 1  2014-07-01 NaN                   NaN             NaN                 282
# 2  2014-08-01 NaN                   NaN             NaN                 282
# 3  2014-08-01 NaN                   NaN             NaN                 282
# 4  2014-09-01 NaN                   NaN             NaN                 282
#
#    datasourceorganization  market_id admin_1 admin_2  dataseries  \
# 0                    2066      57682    Abia    None       15311
# 1                    2066      57682    Abia    None       16409
# 2                    2066      57682    Abia    None       15311
# 3                    2066      57682    Abia    None       16409
# 4                    2066      57682    Abia    None       15311
#
#                                      dataseries_name  \
# 0  Aba, Nigeria (Open Ended): P21421AA - Groundnu...
# 1  Aba, Nigeria (Open Ended): P21421AA - Groundnu...
# 2  Aba, Nigeria (Open Ended): P21421AA - Groundnu...
# 3  Aba, Nigeria (Open Ended): P21421AA - Groundnu...
# 4  Aba, Nigeria (Open Ended): P21421AA - Groundnu...
#
#   dataseries_specialization_type specialization_type data_usage_policy  \
# 0                /MarketProduct/       /MarketPrice/            Public
# 1                /MarketProduct/       /MarketPrice/            Public
# 2                /MarketProduct/       /MarketPrice/            Public
# 3                /MarketProduct/       /MarketPrice/            Public
# 4                /MarketProduct/       /MarketPrice/            Public
#
#                created             modified       status_changed  \
# 0  2015-05-27T18:39:06  2015-12-20T22:57:30  2015-12-20T22:57:30
# 1  2015-05-27T18:39:06  2015-12-20T22:57:30  2015-12-20T22:57:30
# 2  2015-05-27T18:39:30  2015-05-27T18:40:04  2015-05-27T18:40:04
# 3  2015-05-27T18:39:30  2015-05-27T18:40:04  2015-05-27T18:40:04
# 4  2015-05-27T18:40:15  2015-12-20T23:05:51  2015-12-20T23:05:51
#
#   collection_status_changed collection_schedule  is_staple_food
# 0       2015-12-28T22:27:27             Monthly           False
# 1       2015-12-28T22:27:27             Monthly           False
# 2       2015-12-28T22:27:11             Monthly           False
# 3       2015-12-28T22:27:11             Monthly           False
# 4       2015-12-29T00:11:29             Monthly           False
