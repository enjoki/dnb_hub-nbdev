# %% [markdown]
# # Notebook to exlore API visits

# %% [markdown]
# ## import libraries

# %%
# code

# %% [markdown]
# ## Function to make API call and prepare data

# %%
# code

# %% [markdown]
# ## Fetch data from API endpoint

# %%
# code

# %% [markdown]
# ## take a sample of the data

# %%
#code

# %% [markdown]
# ## view the sample

# %% [markdown]
# # Some report
